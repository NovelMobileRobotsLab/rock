# %%
import pandas as pd
import numpy as np

df = pd.read_csv("eval_ckpt100.csv")
display(df)

#read
obs_columns = [f'obs{i}' for i in range(15)]
obs_array = df[obs_columns].to_numpy()

obs_array = np.repeat(obs_array, repeats=3, axis=1) #repeat 3 times to simulate hisotry 3
obs_array.shape
# Out:
#          i          pos0          pos1      pos2      pos3      pos4  \
# 0        0  1.280531e-12 -1.063469e-11  0.079485 -0.329381  0.638058
# 1        1 -1.445797e-04  2.204311e-05  0.078145 -0.327206  0.630577
# 2        2 -6.774534e-04  1.118269e-04  0.076295 -0.318300  0.601431
# 3        3 -1.565450e-03  2.857218e-04  0.074347 -0.301744  0.548986
# 4        4 -2.504574e-03  4.407024e-04  0.075011 -0.304024  0.520185
# ...    ...           ...           ...       ...       ...       ...
# 1995  1995 -3.766739e+00 -3.277933e+00  0.084228 -0.509780 -0.571619
# 1996  1996 -3.767579e+00 -3.275348e+00  0.085586 -0.551003 -0.559997
# 1997  1997 -3.768162e+00 -3.273026e+00  0.086737 -0.586068 -0.547309
# 1998  1998 -3.768490e+00 -3.270978e+00  0.087727 -0.615349 -0.534119
# 1999  1999 -3.768566e+00 -3.269195e+00  0.088550 -0.639615 -0.521253
#
#           pos5       pos6          vel0          vel1  ...          obs5  \
# 0     0.109683   4.483758  1.902642e-10 -2.063931e-09  ...  1.902514e-09
# 1     0.110153   4.460353 -2.722261e-02  4.226616e-03  ...  7.449978e-03
# 2     0.111790   4.368674 -7.422143e-02  1.349404e-02  ...  2.610675e-02
# 3     0.115332   4.190710 -1.037509e-01  1.063832e-02  ... -7.931160e-03
# 4     0.133159   3.940351 -6.914968e-02  2.691511e-02  ... -1.318720e-02
# ...        ...        ...           ...           ...  ...           ...
# 1995 -0.131463 -61.265961 -9.777916e-02  2.718672e-01  ... -1.602299e-01
# 1996 -0.152210 -61.228443 -7.132354e-02  2.454324e-01  ... -1.406870e-01
# 1997 -0.169157 -61.199478 -4.866586e-02  2.215351e-01  ... -1.212841e-01
# 1998 -0.182244 -61.179646 -2.102456e-02  1.919744e-01  ... -1.044726e-01
# 1999 -0.192167 -61.169807  4.386630e-03  1.657573e-01  ... -8.732837e-02
#
#               obs6          obs7          obs8      obs9     obs10     obs11  \
# 0     2.794823e-09  1.709788e-08  5.499154e-09 -0.973978 -0.226644 -0.541211
# 1    -6.047628e-02  2.784250e-02 -1.187891e-01 -0.968407 -0.249376 -0.541211
# 2    -1.808659e-01  8.148204e-02 -3.574739e-01 -0.941509 -0.336987 -0.541211
# 3    -1.505718e-01  1.273290e-01 -5.698186e-01 -0.866984 -0.498336 -0.541211
# 4    -1.425888e-01  1.413529e-01 -7.617055e-01 -0.716491 -0.697597 -0.541211
# ...            ...           ...           ...       ...       ...       ...
# 1995  2.509978e-02  1.184679e-02  1.118374e-01  0.999988  0.004904 -0.612764
# 1996  3.024013e-02  1.198377e-02  8.927076e-02  0.999468 -0.032608 -0.612764
# 1997  3.712259e-02  1.424301e-02  7.001375e-02  0.998105 -0.061540 -0.612764
# 1998  3.691754e-02  1.912802e-02  4.116037e-02  0.996688 -0.081321 -0.612764
# 1999  3.670210e-02  1.935592e-02  1.319695e-02  0.995840 -0.091123 -0.612764
#
#          obs12     obs13     obs14
# 0    -0.840887 -0.894049 -0.447969
# 1    -0.840887 -0.896915 -0.442203
# 2    -0.840887 -0.907651 -0.419725
# 3    -0.840887 -0.925411 -0.378965
# 4    -0.840887 -0.935512 -0.353295
# ...        ...       ...       ...
# 1995  0.790266  0.973483 -0.228759
# 1996  0.790266  0.981142 -0.193289
# 1997  0.790266  0.987165 -0.159704
# 1998  0.790266  0.991711 -0.128487
# 1999  0.790266  0.994960 -0.100270
#
# [2000 rows x 42 columns]
# (2000, 45)

# %%
import matplotlib.pyplot as plt

num_features = obs_array.shape[1]
num_rows = (num_features + 2) // 3  # Calculate rows needed, rounding up
fig, axes = plt.subplots(num_rows, 3, figsize=(15, 4*num_rows))
axes = axes.flatten()

for i in range(num_features):
    ax = axes[i]
    ax.hist(obs_array[:,i], bins=80)
    ax.set_title(f'Feature {i//3},{i%3}')
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')

# Hide any unused subplots
for i in range(num_features, len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# %matplotlib widget
plt.figure()
plt.plot(obs_array[:,0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
